# %% [markdown]
# This file gets the candidagenome.org GO annotations for the genes in important clusters.
#
# In the future, if web scraping is needed to get annotations from C.glabrata or any other species on the candidagenome.org website, this same code can be used with the getURL() function modified as needed. (if the species is still C.glabrata it doesn't need to be changed). To avoid having to run all of the cells again, the serialized object is imported below.

# %%
import _pickle as pickle

pickleIn = open('GOgenes.pickle', 'rb')
genes = pickle.load(pickleIn)
genes = list(genes)
# Out:
# 345

# %%
# These are some commonly used web-scraping libraries
import requests
from bs4 import BeautifulSoup
from time import sleep
import random
import re
from tqdm import tqdm

# %%
# This function generates the URL for each gene to get its genepage on candidagenome.org
def getURL(gene):
    url = 'http://www.candidagenome.org/cgi-bin/locus.pl?locus=' + gene + '&organism=C_glabrata_CBS138'
    # Don't delete the sleep function below, doing so might crash the website!
    sleep(random.uniform(1,3))
    return url

# %%
# This function takes a gene as input and returns a list of its annotations from candidagenome.org
def getAnno(gene):
    url = getURL(gene)

    try:
        # This parses the html to get the annotation information associated with the 'a' tag
        genePage = requests.get(url)
        soup = BeautifulSoup(genePage.text, 'html.parser')
        links = list(soup.find_all('a'))
        
        # Store all the annotations for a gene into a list
        annotations = []
        for link in links:
            link = str(link)
            if 'http://www.candidagenome.org/cgi-bin/GO/go.pl' in link:
                goTermUnfiltered = re.search(r'>.+</a>', link)
                goTerm = goTermUnfiltered.group(0)[1:-4]
                if goTerm == 'molecular_function':
                    annotations.append('unknown molecular function')
                elif goTerm == 'biological_process':
                    annotations.append('unknown biological process')
                elif goTerm == 'cellular_component':
                    annotations.append('unknown cellular component')
                else:
                    annotations.append(goTerm)
        return annotations
    
    # This deals with exceptions if the page doesn't load, or if a gene doesn't exist on the website, etc.
    except:
        return []

# %%
# Collect data and gather info
geneAnno = dict()
for gene in tqdm(genes):
    geneAnno[gene] = getAnno(gene)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 345/345 [22:03<00:00,  3.28s/it]

# %%
pickleOut = open('GOanno.pickle', 'wb')
pickle.dump(geneAnno, pickleOut)

# %%
# Run this to avoid running everything above this point
pickleIn = open('GOanno.pickle', 'rb')
geneAnno = pickle.load(pickleIn)

# %%
# Check how many genes caused an error
count = 0
for gene in geneAnno.keys():
    if len(geneAnno[gene]) == 0:
        print(gene)
        count += 1
        
print('Error Gene Count:', count)
# Out:
# CAGL0M10461s
# CAGL0H00132g
# CAGL0E00209g
# CAGL0I10513g
# CAGL0H00715g
# Error Gene Count: 5

# %% [markdown]
# Upon further inspection of the genes which ran into errors, the website didn't have a GO section for these genes, so the script wasn't the issue.
# Below is a test of the different clusters/groups of interest and their top 5 annotations.

# %%
import pandas as pd

table = pd.read_csv('ClassifiedTable.txt', sep='\t', header=(0), index_col=0)

# %%
# Get gene lists for all target clusters and reference target list

clust5 = table[table.loc[:, 'Prediction'] == 5]
clust5 = list(clust5.index)

clust10 = table[table.loc[:, 'Prediction'] == 10]
clust10 = list(clust10.index)

clust11 = table[table.loc[:, 'Prediction'] == 11]
clust11 = list(clust11.index)

targets = pd.read_csv('TargetGenes.txt', sep= '\t')
targets = list(targets.iloc[:, 0])

# %%
from collections import Counter

freq10 = []
for gene in clust10:
    freq10.extend(geneAnno[gene])
freq10list = [item for item in Counter(freq10).most_common()]
freq10list = [(item, round(num/(len(clust10)), 3)) for item, num in freq10list]
print(freq10list[0:15])

freq5 = []
for gene in clust5:
    freq5.extend(geneAnno[gene])
freq5list = [item for item in Counter(freq5).most_common()]
freq5list = [(item, round(num/(len(clust5)), 3)) for item, num in freq5list]
print(freq5list[0:15])

freq11 = []
for gene in clust5:
    freq11.extend(geneAnno[gene])
freq11list = [item for item in Counter(freq11).most_common()]
freq11list = [(item, round(num/(len(clust11)), 3)) for item, num in freq11list]
print(freq11list[0:15])

freqTarg = []
for gene in targets:
    freqTarg.extend(geneAnno[gene])
freqTarglist = [item for item in Counter(freqTarg).most_common()]
freqTarglist = [(item, round(num/(len(targets)), 3)) for item, num in freqTarglist]
print(freqTarglist[0:15])
# Out:
# [('cellular response to oxidative stress', 1.0), ('oxidation-reduction process', 0.667), ('cytoplasm', 0.667), ('cellular detoxification of hydrogen peroxide', 0.5), ('hydrogen peroxide catabolic process', 0.5), ('thioredoxin peroxidase activity', 0.333), ('cell redox homeostasis', 0.333), ('cytosol', 0.333), ('mitochondrion', 0.333), ('positive regulation of transcription from RNA polymerase II promoter in response to oxidative stress', 0.333), ('catalase activity', 0.333), ('glutathione peroxidase activity', 0.167), ('phospholipid-hydroperoxide glutathione peroxidase activity', 0.167), ('extrinsic component of mitochondrial inner membrane', 0.167), ('extrinsic component of mitochondrial outer membrane', 0.167)]
# [('unknown cellular component', 0.38), ('unknown molecular function', 0.28), ('unknown biological process', 0.2), ('cytosol', 0.16), ('plasma membrane', 0.14), ('cellular response to drug', 0.12), ('cytoplasm', 0.12), ('nucleus', 0.1), ('mitochondrial intermembrane space', 0.08), ('heme biosynthetic process', 0.08), ('mitochondrial matrix', 0.08), ('mitochondrion', 0.08), ('filamentous growth', 0.08), ('pathogenesis', 0.08), ('cellular response to oxidative stress', 0.08)]
# [('unknown cellular component', 0.146), ('unknown molecular function', 0.108), ('unknown biological process', 0.077), ('cytosol', 0.062), ('plasma membrane', 0.054), ('cellular response to drug', 0.046), ('cytoplasm', 0.046), ('nucleus', 0.038), ('mitochondrial intermembrane space', 0.031), ('heme biosynthetic process', 0.031), ('mitochondrial matrix', 0.031), ('mitochondrion', 0.031), ('filamentous growth', 0.031), ('pathogenesis', 0.031), ('cellular response to oxidative stress', 0.031)]
# [('unknown cellular component', 0.364), ('unknown molecular function', 0.262), ('unknown biological process', 0.223), ('nucleus', 0.126), ('cytoplasm', 0.117), ('mitochondrion', 0.107), ('cytosol', 0.107), ('oxidation-reduction process', 0.102), ('plasma membrane', 0.097), ('cellular response to oxidative stress', 0.083), ('ATP binding', 0.063), ('cellular response to drug', 0.063), ('zinc ion binding', 0.058), ('fungal biofilm matrix', 0.053), ('fungal-type cell wall organization', 0.053)]

# %%
anno = []
anno10 = [anno for anno, val in freq10list]
anno.extend(anno10)
anno5 = [anno for anno, val in freq5list]
anno.extend(anno5)
anno11 = [anno for anno, val in freq11list]
anno.extend(anno11)
annoTarg = [anno for anno, val in freqTarglist]
anno.extend(annoTarg)
anno = set(anno)
print(len(anno))
# Out:
# 734

# %%
import pandas as pd

annoTable = pd.DataFrame(index = anno)

for anno, val in freq10list:
    annoTable.loc[anno, 'Extremely High Confidence, N=6'] = val
for anno, val in freq5list:
    annoTable.loc[anno, 'High Confidence, N=50'] = val
for anno, val in freq11list:
    annoTable.loc[anno, 'Low Confidence, N=130'] = val
for anno, val in freqTarglist:
    annoTable.loc[anno, 'Reference Set, N=206'] = val

annoTable.index.rename('GO Annotation', inplace=True)

print(annoTable)
# Out:
#                                                     Extremely High Confidence, N=6  \
# GO Annotation
# NAD binding                                                                    NaN
# thioredoxin peroxidase activity                                              0.333
# cytoplasmic translational elongation                                           NaN
# membrane protein proteolysis                                                   NaN
# protein dephosphorylation                                                      NaN
# autophagy of peroxisome                                                        NaN
# protein quality control for misfolded or incomp...                             NaN
# mediator complex                                                               NaN
# mRNA pseudouridine synthesis                                                   NaN
# hydrogen peroxide catabolic process                                          0.500
# actin cortical patch                                                           NaN
# regulation of transcription by RNA polymerase II                             0.167
# regulation of vacuole fusion, non-autophagic                                   NaN
# Arp2/3 protein complex                                                         NaN
# ascospore-type prospore assembly                                               NaN
# positive regulation of exit from mitosis                                       NaN
# actin filament bundle                                                          NaN
# transmembrane transport                                                        NaN
# cellular oxidant detoxification                                              0.167
# NADPH regeneration                                                             NaN
# protein phosphatase regulator activity                                         NaN
# ribosome                                                                       NaN
# preribosome, large subunit precursor                                           NaN
# protein disulfide oxidoreductase activity                                      NaN
# protein kinase A catalytic subunit binding                                     NaN
# mating projection tip                                                          NaN
# xenobiotic transmembrane transporter activity                                  NaN
# cytosolic large ribosomal subunit                                              NaN
# regulation of nucleosome density                                               NaN
# carboxy-lyase activity                                                         NaN
# ...                                                                            ...
# glutamate-ammonia ligase activity                                              NaN
# establishment of protein-containing complex loc...                             NaN
# protein localization by the Cvt pathway                                        NaN
# protein phosphatase 1 binding                                                  NaN
# transcription elongation from RNA polymerase II...                             NaN
# hydroxymethylbilane synthase activity                                          NaN
# central plaque of spindle pole body                                            NaN
# regulation of phospholipid translocation                                       NaN
# sterol binding                                                                 NaN
# regulation of filamentous growth of a populatio...                             NaN
# mannosyltransferase activity                                                   NaN
# cellular hyperosmotic response                                                 NaN
# pyridoxal phosphate binding                                                    NaN
# acetolactate synthase activity                                                 NaN
# nitrogen compound metabolic process                                            NaN
# mitochondrial genome maintenance                                               NaN
# glyceraldehyde-3-phosphate dehydrogenase (NAD+)...                             NaN
# mitochondrial respiratory chain complex II, suc...                             NaN
# cellular response to heat                                                      NaN
# fumarate reductase (NADH) activity                                             NaN
# branched-chain amino acid biosynthetic process                                 NaN
# ribosomal small subunit export from nucleus                                    NaN
# DNA damage checkpoint                                                          NaN
# calcium ion transmembrane transport                                            NaN
# maintenance of cell polarity                                                   NaN
# lipid droplet                                                                  NaN
# pyruvate decarboxylase activity                                                NaN
# nuclear telomeric heterochromatin                                              NaN
# endocytic recycling                                                            NaN
# biotin biosynthetic process                                                    NaN
#
#                                                     High Confidence, N=50  \
# GO Annotation
# NAD binding                                                           NaN
# thioredoxin peroxidase activity                                      0.02
# cytoplasmic translational elongation                                 0.02
# membrane protein proteolysis                                          NaN
# protein dephosphorylation                                             NaN
# autophagy of peroxisome                                               NaN
# protein quality control for misfolded or incomp...                    NaN
# mediator complex                                                     0.02
# mRNA pseudouridine synthesis                                          NaN
# hydrogen peroxide catabolic process                                  0.02
# actin cortical patch                                                  NaN
# regulation of transcription by RNA polymerase II                      NaN
# regulation of vacuole fusion, non-autophagic                          NaN
# Arp2/3 protein complex                                                NaN
# ascospore-type prospore assembly                                      NaN
# positive regulation of exit from mitosis                             0.02
# actin filament bundle                                                 NaN
# transmembrane transport                                               NaN
# cellular oxidant detoxification                                       NaN
# NADPH regeneration                                                   0.02
# protein phosphatase regulator activity                               0.02
# ribosome                                                              NaN
# preribosome, large subunit precursor                                  NaN
# protein disulfide oxidoreductase activity                            0.02
# protein kinase A catalytic subunit binding                            NaN
# mating projection tip                                                 NaN
# xenobiotic transmembrane transporter activity                        0.02
# cytosolic large ribosomal subunit                                     NaN
# regulation of nucleosome density                                      NaN
# carboxy-lyase activity                                                NaN
# ...                                                                   ...
# glutamate-ammonia ligase activity                                     NaN
# establishment of protein-containing complex loc...                    NaN
# protein localization by the Cvt pathway                              0.02
# protein phosphatase 1 binding                                        0.02
# transcription elongation from RNA polymerase II...                   0.04
# hydroxymethylbilane synthase activity                                0.02
# central plaque of spindle pole body                                   NaN
# regulation of phospholipid translocation                              NaN
# sterol binding                                                        NaN
# regulation of filamentous growth of a populatio...                    NaN
# mannosyltransferase activity                                          NaN
# cellular hyperosmotic response                                       0.02
# pyridoxal phosphate binding                                          0.02
# acetolactate synthase activity                                        NaN
# nitrogen compound metabolic process                                   NaN
# mitochondrial genome maintenance                                      NaN
# glyceraldehyde-3-phosphate dehydrogenase (NAD+)...                    NaN
# mitochondrial respiratory chain complex II, suc...                    NaN
# cellular response to heat                                             NaN
# fumarate reductase (NADH) activity                                    NaN
# branched-chain amino acid biosynthetic process                        NaN
# ribosomal small subunit export from nucleus                           NaN
# DNA damage checkpoint                                                 NaN
# calcium ion transmembrane transport                                   NaN
# maintenance of cell polarity                                          NaN
# lipid droplet                                                        0.04
# pyruvate decarboxylase activity                                       NaN
# nuclear telomeric heterochromatin                                     NaN
# endocytic recycling                                                   NaN
# biotin biosynthetic process                                          0.02
#
#                                                     Low Confidence, N=130  \
# GO Annotation
# NAD binding                                                           NaN
# thioredoxin peroxidase activity                                     0.008
# cytoplasmic translational elongation                                0.008
# membrane protein proteolysis                                          NaN
# protein dephosphorylation                                             NaN
# autophagy of peroxisome                                               NaN
# protein quality control for misfolded or incomp...                    NaN
# mediator complex                                                    0.008
# mRNA pseudouridine synthesis                                          NaN
# hydrogen peroxide catabolic process                                 0.008
# actin cortical patch                                                  NaN
# regulation of transcription by RNA polymerase II                      NaN
# regulation of vacuole fusion, non-autophagic                          NaN
# Arp2/3 protein complex                                                NaN
# ascospore-type prospore assembly                                      NaN
# positive regulation of exit from mitosis                            0.008
# actin filament bundle                                                 NaN
# transmembrane transport                                               NaN
# cellular oxidant detoxification                                       NaN
# NADPH regeneration                                                  0.008
# protein phosphatase regulator activity                              0.008
# ribosome                                                              NaN
# preribosome, large subunit precursor                                  NaN
# protein disulfide oxidoreductase activity                           0.008
# protein kinase A catalytic subunit binding                            NaN
# mating projection tip                                                 NaN
# xenobiotic transmembrane transporter activity                       0.008
# cytosolic large ribosomal subunit                                     NaN
# regulation of nucleosome density                                      NaN
# carboxy-lyase activity                                                NaN
# ...                                                                   ...
# glutamate-ammonia ligase activity                                     NaN
# establishment of protein-containing complex loc...                    NaN
# protein localization by the Cvt pathway                             0.008
# protein phosphatase 1 binding                                       0.008
# transcription elongation from RNA polymerase II...                  0.015
# hydroxymethylbilane synthase activity                               0.008
# central plaque of spindle pole body                                   NaN
# regulation of phospholipid translocation                              NaN
# sterol binding                                                        NaN
# regulation of filamentous growth of a populatio...                    NaN
# mannosyltransferase activity                                          NaN
# cellular hyperosmotic response                                      0.008
# pyridoxal phosphate binding                                         0.008
# acetolactate synthase activity                                        NaN
# nitrogen compound metabolic process                                   NaN
# mitochondrial genome maintenance                                      NaN
# glyceraldehyde-3-phosphate dehydrogenase (NAD+)...                    NaN
# mitochondrial respiratory chain complex II, suc...                    NaN
# cellular response to heat                                             NaN
# fumarate reductase (NADH) activity                                    NaN
# branched-chain amino acid biosynthetic process                        NaN
# ribosomal small subunit export from nucleus                           NaN
# DNA damage checkpoint                                                 NaN
# calcium ion transmembrane transport                                   NaN
# maintenance of cell polarity                                          NaN
# lipid droplet                                                       0.015
# pyruvate decarboxylase activity                                       NaN
# nuclear telomeric heterochromatin                                     NaN
# endocytic recycling                                                   NaN
# biotin biosynthetic process                                         0.008
#
#                                                     Reference Set, N=206
# GO Annotation
# NAD binding                                                        0.010
# thioredoxin peroxidase activity                                    0.019
# cytoplasmic translational elongation                               0.019
# membrane protein proteolysis                                       0.005
# protein dephosphorylation                                          0.005
# autophagy of peroxisome                                            0.005
# protein quality control for misfolded or incomp...                 0.005
# mediator complex                                                   0.010
# mRNA pseudouridine synthesis                                       0.005
# hydrogen peroxide catabolic process                                0.024
# actin cortical patch                                               0.019
# regulation of transcription by RNA polymerase II                   0.015
# regulation of vacuole fusion, non-autophagic                       0.005
# Arp2/3 protein complex                                             0.005
# ascospore-type prospore assembly                                   0.005
# positive regulation of exit from mitosis                             NaN
# actin filament bundle                                              0.005
# transmembrane transport                                            0.024
# cellular oxidant detoxification                                    0.005
# NADPH regeneration                                                 0.005
# protein phosphatase regulator activity                             0.005
# ribosome                                                           0.005
# preribosome, large subunit precursor                               0.005
# protein disulfide oxidoreductase activity                          0.005
# protein kinase A catalytic subunit binding                         0.005
# mating projection tip                                              0.015
# xenobiotic transmembrane transporter activity                      0.010
# cytosolic large ribosomal subunit                                  0.005
# regulation of nucleosome density                                   0.005
# carboxy-lyase activity                                             0.005
# ...                                                                  ...
# glutamate-ammonia ligase activity                                  0.005
# establishment of protein-containing complex loc...                 0.005
# protein localization by the Cvt pathway                            0.005
# protein phosphatase 1 binding                                      0.005
# transcription elongation from RNA polymerase II...                 0.019
# hydroxymethylbilane synthase activity                              0.005
# central plaque of spindle pole body                                0.005
# regulation of phospholipid translocation                           0.005
# sterol binding                                                     0.005
# regulation of filamentous growth of a populatio...                 0.005
# mannosyltransferase activity                                       0.005
# cellular hyperosmotic response                                     0.005
# pyridoxal phosphate binding                                        0.015
# acetolactate synthase activity                                     0.005
# nitrogen compound metabolic process                                0.005
# mitochondrial genome maintenance                                   0.010
# glyceraldehyde-3-phosphate dehydrogenase (NAD+)...                 0.005
# mitochondrial respiratory chain complex II, suc...                 0.005
# cellular response to heat                                          0.010
# fumarate reductase (NADH) activity                                 0.005
# branched-chain amino acid biosynthetic process                     0.010
# ribosomal small subunit export from nucleus                        0.005
# DNA damage checkpoint                                              0.005
# calcium ion transmembrane transport                                0.005
# maintenance of cell polarity                                       0.005
# lipid droplet                                                      0.019
# pyruvate decarboxylase activity                                    0.005
# nuclear telomeric heterochromatin                                  0.005
# endocytic recycling                                                0.005
# biotin biosynthetic process                                        0.005
# [734 rows x 4 columns]

# %%
testAnnoFrame = annoTable.copy(deep=True)
testAnnoFrame = testAnnoFrame.fillna(0)
try:
    del testAnnoFrame['Sum']
except:
    pass
rowSum = testAnnoFrame.sum(axis=1)
annoTable['Sum'] = rowSum

annoTable = annoTable.sort_values(by='Sum', ascending=False)
del annoTable['Sum']

# print(annoTable)

# for ele in annoTable.head(20).index:
#     print(annoTable.loc[ele, :], '\n')
# Out:
#                                                     Extremely High Confidence, N=6  \
# GO Annotation
# cellular response to oxidative stress                                        1.000
# unknown cellular component                                                   0.167
# cytoplasm                                                                    0.667
# oxidation-reduction process                                                  0.667
# cytosol                                                                      0.333
# unknown molecular function                                                     NaN
# hydrogen peroxide catabolic process                                          0.500
# mitochondrion                                                                0.333
# cellular detoxification of hydrogen peroxide                                 0.500
# unknown biological process                                                     NaN
# nucleus                                                                      0.167
# cell redox homeostasis                                                       0.333
# cellular response to drug                                                    0.167
# thioredoxin peroxidase activity                                              0.333
# positive regulation of transcription from RNA p...                           0.333
# catalase activity                                                            0.333
# pathogenesis                                                                 0.167
# plasma membrane                                                                NaN
# positive regulation of transcription by RNA pol...                           0.167
# RNA polymerase II proximal promoter sequence-sp...                           0.167
# DNA-binding transcription factor activity                                    0.167
# nuclear chromatin                                                            0.167
# response to oxidative stress                                                 0.167
# DNA-binding transcription activator activity, R...                           0.167
# DNA binding                                                                  0.167
# peroxisome                                                                   0.167
# apoptotic process                                                            0.167
# regulation of transcription from RNA polymerase...                           0.167
# transcription regulatory region DNA binding                                  0.167
# unfolded protein binding                                                     0.167
# ...                                                                            ...
# anthranilate phosphoribosyltransferase activity                                NaN
# amino acid transport                                                           NaN
# protein K11-linked deubiquitination                                            NaN
# isoleucine biosynthetic process                                                NaN
# maintenance of cell polarity                                                   NaN
# DNA damage checkpoint                                                          NaN
# positive regulation of TORC1 signaling                                         NaN
# ribosomal small subunit export from nucleus                                    NaN
# D-xylose metabolic process                                                     NaN
# lipid binding                                                                  NaN
# 1-acylglycerol-3-phosphate O-acyltransferase ac...                             NaN
# positive regulation of cell wall organization o...                             NaN
# proton binding                                                                 NaN
# establishment or maintenance of cell polarity r...                             NaN
# central plaque of spindle pole body                                            NaN
# regulation of phospholipid translocation                                       NaN
# sterol binding                                                                 NaN
# regulation of filamentous growth of a populatio...                             NaN
# mannosyltransferase activity                                                   NaN
# regulation of vacuole fusion, non-autophagic                                   NaN
# mRNA pseudouridine synthesis                                                   NaN
# acetolactate synthase activity                                                 NaN
# nitrogen compound metabolic process                                            NaN
# protein quality control for misfolded or incomp...                             NaN
# glyceraldehyde-3-phosphate dehydrogenase (NAD+)...                             NaN
# mitochondrial respiratory chain complex II, suc...                             NaN
# autophagy of peroxisome                                                        NaN
# fumarate reductase (NADH) activity                                             NaN
# protein dephosphorylation                                                      NaN
# chromatin remodeling                                                           NaN
#
#                                                     High Confidence, N=50  \
# GO Annotation
# cellular response to oxidative stress                                0.08
# unknown cellular component                                           0.38
# cytoplasm                                                            0.12
# oxidation-reduction process                                          0.06
# cytosol                                                              0.16
# unknown molecular function                                           0.28
# hydrogen peroxide catabolic process                                  0.02
# mitochondrion                                                        0.08
# cellular detoxification of hydrogen peroxide                          NaN
# unknown biological process                                           0.20
# nucleus                                                              0.10
# cell redox homeostasis                                               0.04
# cellular response to drug                                            0.12
# thioredoxin peroxidase activity                                      0.02
# positive regulation of transcription from RNA p...                   0.02
# catalase activity                                                     NaN
# pathogenesis                                                         0.08
# plasma membrane                                                      0.14
# positive regulation of transcription by RNA pol...                   0.04
# RNA polymerase II proximal promoter sequence-sp...                   0.04
# DNA-binding transcription factor activity                            0.04
# nuclear chromatin                                                    0.04
# response to oxidative stress                                         0.04
# DNA-binding transcription activator activity, R...                   0.04
# DNA binding                                                          0.02
# peroxisome                                                           0.02
# apoptotic process                                                    0.02
# regulation of transcription from RNA polymerase...                   0.02
# transcription regulatory region DNA binding                          0.02
# unfolded protein binding                                             0.02
# ...                                                                   ...
# anthranilate phosphoribosyltransferase activity                       NaN
# amino acid transport                                                  NaN
# protein K11-linked deubiquitination                                   NaN
# isoleucine biosynthetic process                                       NaN
# maintenance of cell polarity                                          NaN
# DNA damage checkpoint                                                 NaN
# positive regulation of TORC1 signaling                                NaN
# ribosomal small subunit export from nucleus                           NaN
# D-xylose metabolic process                                            NaN
# lipid binding                                                         NaN
# 1-acylglycerol-3-phosphate O-acyltransferase ac...                    NaN
# positive regulation of cell wall organization o...                    NaN
# proton binding                                                        NaN
# establishment or maintenance of cell polarity r...                    NaN
# central plaque of spindle pole body                                   NaN
# regulation of phospholipid translocation                              NaN
# sterol binding                                                        NaN
# regulation of filamentous growth of a populatio...                    NaN
# mannosyltransferase activity                                          NaN
# regulation of vacuole fusion, non-autophagic                          NaN
# mRNA pseudouridine synthesis                                          NaN
# acetolactate synthase activity                                        NaN
# nitrogen compound metabolic process                                   NaN
# protein quality control for misfolded or incomp...                    NaN
# glyceraldehyde-3-phosphate dehydrogenase (NAD+)...                    NaN
# mitochondrial respiratory chain complex II, suc...                    NaN
# autophagy of peroxisome                                               NaN
# fumarate reductase (NADH) activity                                    NaN
# protein dephosphorylation                                             NaN
# chromatin remodeling                                                  NaN
#
#                                                     Low Confidence, N=130  \
# GO Annotation
# cellular response to oxidative stress                               0.031
# unknown cellular component                                          0.146
# cytoplasm                                                           0.046
# oxidation-reduction process                                         0.023
# cytosol                                                             0.062
# unknown molecular function                                          0.108
# hydrogen peroxide catabolic process                                 0.008
# mitochondrion                                                       0.031
# cellular detoxification of hydrogen peroxide                          NaN
# unknown biological process                                          0.077
# nucleus                                                             0.038
# cell redox homeostasis                                              0.015
# cellular response to drug                                           0.046
# thioredoxin peroxidase activity                                     0.008
# positive regulation of transcription from RNA p...                  0.008
# catalase activity                                                     NaN
# pathogenesis                                                        0.031
# plasma membrane                                                     0.054
# positive regulation of transcription by RNA pol...                  0.015
# RNA polymerase II proximal promoter sequence-sp...                  0.015
# DNA-binding transcription factor activity                           0.015
# nuclear chromatin                                                   0.015
# response to oxidative stress                                        0.015
# DNA-binding transcription activator activity, R...                  0.015
# DNA binding                                                         0.008
# peroxisome                                                          0.008
# apoptotic process                                                   0.008
# regulation of transcription from RNA polymerase...                  0.008
# transcription regulatory region DNA binding                         0.008
# unfolded protein binding                                            0.008
# ...                                                                   ...
# anthranilate phosphoribosyltransferase activity                       NaN
# amino acid transport                                                  NaN
# protein K11-linked deubiquitination                                   NaN
# isoleucine biosynthetic process                                       NaN
# maintenance of cell polarity                                          NaN
# DNA damage checkpoint                                                 NaN
# positive regulation of TORC1 signaling                                NaN
# ribosomal small subunit export from nucleus                           NaN
# D-xylose metabolic process                                            NaN
# lipid binding                                                         NaN
# 1-acylglycerol-3-phosphate O-acyltransferase ac...                    NaN
# positive regulation of cell wall organization o...                    NaN
# proton binding                                                        NaN
# establishment or maintenance of cell polarity r...                    NaN
# central plaque of spindle pole body                                   NaN
# regulation of phospholipid translocation                              NaN
# sterol binding                                                        NaN
# regulation of filamentous growth of a populatio...                    NaN
# mannosyltransferase activity                                          NaN
# regulation of vacuole fusion, non-autophagic                          NaN
# mRNA pseudouridine synthesis                                          NaN
# acetolactate synthase activity                                        NaN
# nitrogen compound metabolic process                                   NaN
# protein quality control for misfolded or incomp...                    NaN
# glyceraldehyde-3-phosphate dehydrogenase (NAD+)...                    NaN
# mitochondrial respiratory chain complex II, suc...                    NaN
# autophagy of peroxisome                                               NaN
# fumarate reductase (NADH) activity                                    NaN
# protein dephosphorylation                                             NaN
# chromatin remodeling                                                  NaN
#
#                                                     Reference Set, N=206
# GO Annotation
# cellular response to oxidative stress                              0.083
# unknown cellular component                                         0.364
# cytoplasm                                                          0.117
# oxidation-reduction process                                        0.102
# cytosol                                                            0.107
# unknown molecular function                                         0.262
# hydrogen peroxide catabolic process                                0.024
# mitochondrion                                                      0.107
# cellular detoxification of hydrogen peroxide                       0.015
# unknown biological process                                         0.223
# nucleus                                                            0.126
# cell redox homeostasis                                             0.029
# cellular response to drug                                          0.063
# thioredoxin peroxidase activity                                    0.019
# positive regulation of transcription from RNA p...                 0.015
# catalase activity                                                  0.010
# pathogenesis                                                       0.049
# plasma membrane                                                    0.097
# positive regulation of transcription by RNA pol...                 0.044
# RNA polymerase II proximal promoter sequence-sp...                 0.024
# DNA-binding transcription factor activity                          0.024
# nuclear chromatin                                                  0.024
# response to oxidative stress                                       0.015
# DNA-binding transcription activator activity, R...                 0.015
# DNA binding                                                        0.034
# peroxisome                                                         0.029
# apoptotic process                                                  0.015
# regulation of transcription from RNA polymerase...                 0.015
# transcription regulatory region DNA binding                        0.015
# unfolded protein binding                                           0.015
# ...                                                                  ...
# anthranilate phosphoribosyltransferase activity                    0.005
# amino acid transport                                               0.005
# protein K11-linked deubiquitination                                0.005
# isoleucine biosynthetic process                                    0.005
# maintenance of cell polarity                                       0.005
# DNA damage checkpoint                                              0.005
# positive regulation of TORC1 signaling                             0.005
# ribosomal small subunit export from nucleus                        0.005
# D-xylose metabolic process                                         0.005
# lipid binding                                                      0.005
# 1-acylglycerol-3-phosphate O-acyltransferase ac...                 0.005
# positive regulation of cell wall organization o...                 0.005
# proton binding                                                     0.005
# establishment or maintenance of cell polarity r...                 0.005
# central plaque of spindle pole body                                0.005
# regulation of phospholipid translocation                           0.005
# sterol binding                                                     0.005
# regulation of filamentous growth of a populatio...                 0.005
# mannosyltransferase activity                                       0.005
# regulation of vacuole fusion, non-autophagic                       0.005
# mRNA pseudouridine synthesis                                       0.005
# acetolactate synthase activity                                     0.005
# nitrogen compound metabolic process                                0.005
# protein quality control for misfolded or incomp...                 0.005
# glyceraldehyde-3-phosphate dehydrogenase (NAD+)...                 0.005
# mitochondrial respiratory chain complex II, suc...                 0.005
# autophagy of peroxisome                                            0.005
# fumarate reductase (NADH) activity                                 0.005
# protein dephosphorylation                                          0.005
# chromatin remodeling                                               0.005
# [734 rows x 4 columns]
# Extremely High Confidence, N=6    1.000
# High Confidence, N=50             0.080
# Low Confidence, N=130             0.031
# Reference Set, N=206              0.083
# Name: cellular response to oxidative stress, dtype: float64
#
# Extremely High Confidence, N=6    0.167
# High Confidence, N=50             0.380
# Low Confidence, N=130             0.146
# Reference Set, N=206              0.364
# Name: unknown cellular component, dtype: float64
#
# Extremely High Confidence, N=6    0.667
# High Confidence, N=50             0.120
# Low Confidence, N=130             0.046
# Reference Set, N=206              0.117
# Name: cytoplasm, dtype: float64
#
# Extremely High Confidence, N=6    0.667
# High Confidence, N=50             0.060
# Low Confidence, N=130             0.023
# Reference Set, N=206              0.102
# Name: oxidation-reduction process, dtype: float64
#
# Extremely High Confidence, N=6    0.333
# High Confidence, N=50             0.160
# Low Confidence, N=130             0.062
# Reference Set, N=206              0.107
# Name: cytosol, dtype: float64
#
# Extremely High Confidence, N=6      NaN
# High Confidence, N=50             0.280
# Low Confidence, N=130             0.108
# Reference Set, N=206              0.262
# Name: unknown molecular function, dtype: float64
#
# Extremely High Confidence, N=6    0.500
# High Confidence, N=50             0.020
# Low Confidence, N=130             0.008
# Reference Set, N=206              0.024
# Name: hydrogen peroxide catabolic process, dtype: float64
#
# Extremely High Confidence, N=6    0.333
# High Confidence, N=50             0.080
# Low Confidence, N=130             0.031
# Reference Set, N=206              0.107
# Name: mitochondrion, dtype: float64
#
# Extremely High Confidence, N=6    0.500
# High Confidence, N=50               NaN
# Low Confidence, N=130               NaN
# Reference Set, N=206              0.015
# Name: cellular detoxification of hydrogen peroxide, dtype: float64
#
# Extremely High Confidence, N=6      NaN
# High Confidence, N=50             0.200
# Low Confidence, N=130             0.077
# Reference Set, N=206              0.223
# Name: unknown biological process, dtype: float64
#
# Extremely High Confidence, N=6    0.167
# High Confidence, N=50             0.100
# Low Confidence, N=130             0.038
# Reference Set, N=206              0.126
# Name: nucleus, dtype: float64
#
# Extremely High Confidence, N=6    0.333
# High Confidence, N=50             0.040
# Low Confidence, N=130             0.015
# Reference Set, N=206              0.029
# Name: cell redox homeostasis, dtype: float64
#
# Extremely High Confidence, N=6    0.167
# High Confidence, N=50             0.120
# Low Confidence, N=130             0.046
# Reference Set, N=206              0.063
# Name: cellular response to drug, dtype: float64
#
# Extremely High Confidence, N=6    0.333
# High Confidence, N=50             0.020
# Low Confidence, N=130             0.008
# Reference Set, N=206              0.019
# Name: thioredoxin peroxidase activity, dtype: float64
#
# Extremely High Confidence, N=6    0.333
# High Confidence, N=50             0.020
# Low Confidence, N=130             0.008
# Reference Set, N=206              0.015
# Name: positive regulation of transcription from RNA polymerase II promoter in response to oxidative stress, dtype: float64
#
# Extremely High Confidence, N=6    0.333
# High Confidence, N=50               NaN
# Low Confidence, N=130               NaN
# Reference Set, N=206              0.010
# Name: catalase activity, dtype: float64
#
# Extremely High Confidence, N=6    0.167
# High Confidence, N=50             0.080
# Low Confidence, N=130             0.031
# Reference Set, N=206              0.049
# Name: pathogenesis, dtype: float64
#
# Extremely High Confidence, N=6      NaN
# High Confidence, N=50             0.140
# Low Confidence, N=130             0.054
# Reference Set, N=206              0.097
# Name: plasma membrane, dtype: float64
#
# Extremely High Confidence, N=6    0.167
# High Confidence, N=50             0.040
# Low Confidence, N=130             0.015
# Reference Set, N=206              0.044
# Name: positive regulation of transcription by RNA polymerase II, dtype: float64
#
# Extremely High Confidence, N=6    0.167
# High Confidence, N=50             0.040
# Low Confidence, N=130             0.015
# Reference Set, N=206              0.024
# Name: RNA polymerase II proximal promoter sequence-specific DNA binding, dtype: float64

# %%
annoTable.to_csv("AnnotationFrequency.csv", sep=",", index=True)

# %%
import _pickle as pickle

# Run this to avoid running everything above this point
pickleIn = open('GOanno.pickle', 'rb')
geneAnno = pickle.load(pickleIn)
print(len(geneAnno.keys()))
print(clust10)
print(clust5)
print(clust11)
# Out:
# 345
# ['CAGL0C01705g', 'CAGL0H04631g', 'CAGL0I01166g', 'CAGL0K06259g', 'CAGL0K10868g', 'CAGL0L05258g']
# ['CAGL0B01419g', 'CAGL0B02607g', 'CAGL0B03069g', 'CAGL0C01727g', 'CAGL0D01496g', 'CAGL0D05434g', 'CAGL0D05478g', 'CAGL0D06138g', 'CAGL0E05170g', 'CAGL0F01793g', 'CAGL0F07359g', 'CAGL0F07513g', 'CAGL0F09097g', 'CAGL0G03223g', 'CAGL0G06182g', 'CAGL0G09405r', 'CAGL0H00704g', 'CAGL0H01375g', 'CAGL0H02739g', 'CAGL0H04653g', 'CAGL0H05951g', 'CAGL0H06017g', 'CAGL0H10142g', 'CAGL0I00726g', 'CAGL0I00748g', 'CAGL0I04884g', 'CAGL0J07612g', 'CAGL0J09680g', 'CAGL0K00803g', 'CAGL0K01727g', 'CAGL0K03531g', 'CAGL0K03553g', 'CAGL0K08162g', 'CAGL0K08184g', 'CAGL0K09350g', 'CAGL0K10879g', 'CAGL0K11858g', 'CAGL0K11880g', 'CAGL0L04664g', 'CAGL0L05280g', 'CAGL0L05742g', 'CAGL0L13365r', 'CAGL0L13376g', 'CAGL0L13387r', 'CAGL0L13392g', 'CAGL0M02607g', 'CAGL0M02629g', 'CAGL0M05819g', 'CAGL0M11682g', 'CAGL0M11704g']
# ['CAGL0A00495g', 'CAGL0A00517g', 'CAGL0B00990g', 'CAGL0B01188g', 'CAGL0B01203g', 'CAGL0B02651g', 'CAGL0B02673g', 'CAGL0B03685g', 'CAGL0B04257g', 'CAGL0B04279g', 'CAGL0B04301g', 'CAGL0C00253g', 'CAGL0C01661g', 'CAGL0C01683g', 'CAGL0C03355g', 'CAGL0C03531g', 'CAGL0C03597g', 'CAGL0C03608g', 'CAGL0D00572g', 'CAGL0D02134g', 'CAGL0D02150g', 'CAGL0D03256g', 'CAGL0D03278g', 'CAGL0D05456g', 'CAGL0E00187g', 'CAGL0E01353g', 'CAGL0E04774g', 'CAGL0E04884g', 'CAGL0E05390g', 'CAGL0E05412g', 'CAGL0F00715g', 'CAGL0F00737g', 'CAGL0F00869g', 'CAGL0F02717g', 'CAGL0F02893g', 'CAGL0F03069g', 'CAGL0F03113g', 'CAGL0F04983g', 'CAGL0F05137g', 'CAGL0F05247g', 'CAGL0F06611g', 'CAGL0F08833g', 'CAGL0G01672g', 'CAGL0G01694g', 'CAGL0G02079g', 'CAGL0G04873g', 'CAGL0G04895g', 'CAGL0G05027g', 'CAGL0G05467g', 'CAGL0G05808g', 'CAGL0G06512r', 'CAGL0G07469g', 'CAGL0G07491g', 'CAGL0G07865g', 'CAGL0G08195g', 'CAGL0H03289g', 'CAGL0H06853g', 'CAGL0H09130g', 'CAGL0H09988g', 'CAGL0I00440g', 'CAGL0I00572g', 'CAGL0I00946g', 'CAGL0I01320g', 'CAGL0I01870g', 'CAGL0I02442g', 'CAGL0I02464g', 'CAGL0I02574g', 'CAGL0I03432g', 'CAGL0I04004g', 'CAGL0I05236g', 'CAGL0I05390g', 'CAGL0I08635g', 'CAGL0I09108g', 'CAGL0I09130g', 'CAGL0I09504g', 'CAGL0J00561g', 'CAGL0J00583g', 'CAGL0J01067g', 'CAGL0J04664g', 'CAGL0J05346g', 'CAGL0J06380g', 'CAGL0J07502g', 'CAGL0J07568g', 'CAGL0J07590g', 'CAGL0J10758g', 'CAGL0K00759g', 'CAGL0K00781g', 'CAGL0K02739g', 'CAGL0K02761g', 'CAGL0K03443g', 'CAGL0K03459g', 'CAGL0K03465g', 'CAGL0K04653g', 'CAGL0K05379g', 'CAGL0K05797g', 'CAGL0K05813g', 'CAGL0K11572g', 'CAGL0K11836g', 'CAGL0K12804g', 'CAGL0K12826g', 'CAGL0L02519g', 'CAGL0L02541g', 'CAGL0L04686g', 'CAGL0L05236g', 'CAGL0L05720g', 'CAGL0L06072g', 'CAGL0L06732g', 'CAGL0L08734g', 'CAGL0L08756g', 'CAGL0L10560g', 'CAGL0L12386g', 'CAGL0M00836g', 'CAGL0M03305g', 'CAGL0M04081g', 'CAGL0M04213g', 'CAGL0M05467g', 'CAGL0M05995g', 'CAGL0M06325g', 'CAGL0M06347g', 'CAGL0M07315g', 'CAGL0M07689r', 'CAGL0M07691r', 'CAGL0M07693r', 'CAGL0M07695r', 'CAGL0M07700g', 'CAGL0M08470r', 'CAGL0M08514g', 'CAGL0M10461s', 'CAGL0M11572g', 'CAGL0M11660g']

# %%
key_phrases = ['cell wall', 'hyph']
counter_list = []
anno_list = []

targets = clust5 + clust10 + clust11

for gene in targets:
    for anno in geneAnno[gene]:
        for phrase in key_phrases:
            if phrase in anno:
                counter_list.append(gene)
                anno_list.append(anno)
            
print(str(len(set(counter_list))) + ' genes found in CgYap1 target list related to keywords: ', str(key_phrases))
print('Genes: ', set(counter_list))
print('Annotations: ',set(anno_list))
# Out:
# 14 genes found in CgYap1 target list related to keywords:  ['cell wall', 'hyph']
# Genes:  {'CAGL0F05137g', 'CAGL0H09130g', 'CAGL0H01375g', 'CAGL0B03069g', 'CAGL0G04873g', 'CAGL0M08514g', 'CAGL0D03256g', 'CAGL0K09350g', 'CAGL0F08833g', 'CAGL0G07491g', 'CAGL0M11704g', 'CAGL0G05027g', 'CAGL0E05412g', 'CAGL0I05390g'}
# Annotations:  {'cell wall mannoprotein biosynthetic process', 'hyphal growth', 'fungal-type cell wall organization', 'fungal-type cell wall biogenesis', 'fungal-type cell wall polysaccharide biosynthetic process', 'fungal-type cell wall', 'regulation of cell wall (1-&gt;3)-beta-D-glucan biosynthetic process', 'pseudohyphal growth', 'positive regulation of pseudohyphal growth', 'hyphal cell wall', 'regulation of fungal-type cell wall organization', 'fungal-type cell wall beta-glucan biosynthetic process', 'yeast-form cell wall'}
